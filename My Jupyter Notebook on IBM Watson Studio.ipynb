# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# **Deygerson Méndez**
#
# Systems analyst

# %% [markdown]
# *I´m interested in data science, because I´m interested in learning about machine learning and AI.*

# %% [markdown]
# <h3>In the following code, a function is shown that multiplies 2 numerical values.</h3>

# %%
def multiply(num1,num2):

    num3=num1*num2
    print(num3)
    
multiply(2,4)
# Out:
# 8

# %% [markdown]
# <ol>
#   <strong><p>Order list</p></strong>
#   <li>This is question one.</li>
#   <li>This is question two.</li>
#   <li>This is question three.</li>
#   <li>This is question four.</li>
# </ol>
#
#
# <ul>
#  <strong><p>Unorder list</p></strong>
#   <li>This is question one.</li>
#   <li>This is question two.</li>
#   <li>This is question three.</li>
#   <li>This is question four.</li>
# </ul>
#
# <strong><p>Image</p></strong>
#
# ![Captura%20de%20pantalla%202021-07-02%20152946.jpg](attachment:Captura%20de%20pantalla%202021-07-02%20152946.jpg)
